# %% [markdown]
# <a href="https://colab.research.google.com/github/amalsalilan/B3-Developing-Named-Entity-Recognition-NER-Models-for-Financial-Data-Extraction-/blob/rishwanth/doclingprocess.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install spacy docling
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.12/dist-packages (3.8.7)
# Collecting docling
#   Downloading docling-2.58.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.12/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy) (3.0.10)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.12/dist-packages (from spacy) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (0.20.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.32.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.11.10)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from spacy) (75.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (25.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (3.5.0)
# Collecting docling-core<3.0.0,>=2.48.2 (from docling-core[chunking]<3.0.0,>=2.48.2->docling)
#   Downloading docling_core-2.49.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting docling-parse<5.0.0,>=4.7.0 (from docling)
#   Downloading docling_parse-4.7.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (10 kB)
# Collecting docling-ibm-models<4,>=3.9.1 (from docling)
#   Downloading docling_ibm_models-3.10.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting filetype<2.0.0,>=1.2.0 (from docling)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting pypdfium2!=4.30.1,<5.0.0,>=4.30.0 (from docling)
#   Downloading pypdfium2-4.30.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from docling) (2.11.0)
# Requirement already satisfied: huggingface_hub<1,>=0.23 in /usr/local/lib/python3.12/dist-packages (from docling) (0.36.0)
# Collecting rapidocr<4.0.0,>=3.3 (from docling)
#   Downloading rapidocr-3.4.2-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: certifi>=2024.7.4 in /usr/local/lib/python3.12/dist-packages (from docling) (2025.10.5)
# Collecting rtree<2.0.0,>=1.3.0 (from docling)
#   Downloading rtree-1.4.1-py3-none-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Collecting typer<1.0.0,>=0.3.0 (from spacy)
#   Downloading typer-0.19.2-py3-none-any.whl.metadata (16 kB)
# Collecting python-docx<2.0.0,>=1.1.2 (from docling)
#   Downloading python_docx-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting python-pptx<2.0.0,>=1.0.2 (from docling)
#   Downloading python_pptx-1.0.2-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /usr/local/lib/python3.12/dist-packages (from docling) (4.13.5)
# Requirement already satisfied: pandas<3.0.0,>=2.1.4 in /usr/local/lib/python3.12/dist-packages (from docling) (2.2.2)
# Collecting marko<3.0.0,>=2.1.2 (from docling)
#   Downloading marko-2.2.1-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: openpyxl<4.0.0,>=3.1.5 in /usr/local/lib/python3.12/dist-packages (from docling) (3.1.5)
# Requirement already satisfied: lxml<6.0.0,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from docling) (5.4.0)
# Requirement already satisfied: pillow<12.0.0,>=10.0.0 in /usr/local/lib/python3.12/dist-packages (from docling) (11.3.0)
# Requirement already satisfied: pluggy<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from docling) (1.6.0)
# Collecting pylatexenc<3.0,>=2.10 (from docling)
#   Downloading pylatexenc-2.10.tar.gz (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 8.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scipy<2.0.0,>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from docling) (1.16.2)
# Requirement already satisfied: accelerate<2,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from docling) (1.11.0)
# Collecting polyfactory>=2.22.2 (from docling)
#   Downloading polyfactory-2.22.3-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate<2,>=1.0.0->docling) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate<2,>=1.0.0->docling) (6.0.3)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from accelerate<2,>=1.0.0->docling) (2.8.0+cu126)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate<2,>=1.0.0->docling) (0.6.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4<5.0.0,>=4.12.3->docling) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4<5.0.0,>=4.12.3->docling) (4.15.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.16.0 in /usr/local/lib/python3.12/dist-packages (from docling-core<3.0.0,>=2.48.2->docling-core[chunking]<3.0.0,>=2.48.2->docling) (4.25.1)
# Collecting jsonref<2.0.0,>=1.1.0 (from docling-core<3.0.0,>=2.48.2->docling-core[chunking]<3.0.0,>=2.48.2->docling)
#   Downloading jsonref-1.1.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from docling-core<3.0.0,>=2.48.2->docling-core[chunking]<3.0.0,>=2.48.2->docling) (0.9.0)
# Collecting latex2mathml<4.0.0,>=3.77.0 (from docling-core<3.0.0,>=2.48.2->docling-core[chunking]<3.0.0,>=2.48.2->docling)
#   Downloading latex2mathml-3.78.1-py3-none-any.whl.metadata (15 kB)
# Collecting semchunk<3.0.0,>=2.2.0 (from docling-core[chunking]<3.0.0,>=2.48.2->docling)
#   Downloading semchunk-2.2.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /usr/local/lib/python3.12/dist-packages (from docling-core[chunking]<3.0.0,>=2.48.2->docling) (4.57.1)
# Requirement already satisfied: torchvision<1,>=0 in /usr/local/lib/python3.12/dist-packages (from docling-ibm-models<4,>=3.9.1->docling) (0.23.0+cu126)
# Collecting jsonlines<5.0.0,>=3.1.0 (from docling-ibm-models<4,>=3.9.1->docling)
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub<1,>=0.23->docling) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub<1,>=0.23->docling) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub<1,>=0.23->docling) (1.2.0)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.12/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl<4.0.0,>=3.1.5->docling) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.1.4->docling) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.1.4->docling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.1.4->docling) (2025.2)
# Collecting faker>=5.0.0 (from polyfactory>=2.22.2->docling)
#   Downloading faker-37.12.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.3.0->docling) (1.1.1)
# Collecting XlsxWriter>=0.5.7 (from python-pptx<2.0.0,>=1.0.2->docling)
#   Downloading xlsxwriter-3.2.9-py3-none-any.whl.metadata (2.7 kB)
# Collecting pyclipper>=1.2.0 (from rapidocr<4.0.0,>=3.3->docling)
#   Downloading pyclipper-1.3.0.post6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: opencv-python>=4.5.1.48 in /usr/local/lib/python3.12/dist-packages (from rapidocr<4.0.0,>=3.3->docling) (4.12.0.88)
# Requirement already satisfied: six>=1.15.0 in /usr/local/lib/python3.12/dist-packages (from rapidocr<4.0.0,>=3.3->docling) (1.17.0)
# Requirement already satisfied: Shapely!=2.0.4,>=1.7.1 in /usr/local/lib/python3.12/dist-packages (from rapidocr<4.0.0,>=3.3->docling) (2.1.2)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.12/dist-packages (from rapidocr<4.0.0,>=3.3->docling) (2.3.0)
# Collecting colorlog (from rapidocr<4.0.0,>=3.3->docling)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.5.0)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->spacy) (3.0.3)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonlines<5.0.0,>=3.1.0->docling-ibm-models<4,>=3.9.1->docling) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.48.2->docling-core[chunking]<3.0.0,>=2.48.2->docling) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.48.2->docling-core[chunking]<3.0.0,>=2.48.2->docling) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.48.2->docling-core[chunking]<3.0.0,>=2.48.2->docling) (0.28.0)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.3.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Collecting mpire[dill] (from semchunk<3.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.48.2->docling)
#   Downloading mpire-2.10.2-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (2.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate<2,>=1.0.0->docling) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate<2,>=1.0.0->docling) (3.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate<2,>=1.0.0->docling) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate<2,>=1.0.0->docling) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate<2,>=1.0.0->docling) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate<2,>=1.0.0->docling) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate<2,>=1.0.0->docling) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate<2,>=1.0.0->docling) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate<2,>=1.0.0->docling) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate<2,>=1.0.0->docling) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate<2,>=1.0.0->docling) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate<2,>=1.0.0->docling) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate<2,>=1.0.0->docling) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate<2,>=1.0.0->docling) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate<2,>=1.0.0->docling) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate<2,>=1.0.0->docling) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate<2,>=1.0.0->docling) (3.4.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.34.0->docling-core[chunking]<3.0.0,>=2.48.2->docling) (2024.11.6)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.34.0->docling-core[chunking]<3.0.0,>=2.48.2->docling) (0.22.1)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf->rapidocr<4.0.0,>=3.3->docling) (4.9.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate<2,>=1.0.0->docling) (1.3.0)
# Requirement already satisfied: multiprocess>=0.70.15 in /usr/local/lib/python3.12/dist-packages (from mpire[dill]->semchunk<3.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.48.2->docling) (0.70.16)
# Requirement already satisfied: dill>=0.3.8 in /usr/local/lib/python3.12/dist-packages (from multiprocess>=0.70.15->mpire[dill]->semchunk<3.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.48.2->docling) (0.3.8)
# Downloading docling-2.58.0-py3-none-any.whl (251 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.4/251.4 kB 16.5 MB/s eta 0:00:00
# Downloading docling_core-2.49.0-py3-none-any.whl (164 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.5/164.5 kB 10.5 MB/s eta 0:00:00
# Downloading docling_ibm_models-3.10.2-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.4/87.4 kB 6.2 MB/s eta 0:00:00
# Downloading docling_parse-4.7.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (15.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 83.4 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading marko-2.2.1-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 kB 3.1 MB/s eta 0:00:00
# Downloading polyfactory-2.22.3-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 4.9 MB/s eta 0:00:00
# Downloading pypdfium2-4.30.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 86.8 MB/s eta 0:00:00
# Downloading python_docx-1.2.0-py3-none-any.whl (252 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 17.2 MB/s eta 0:00:00
# Downloading python_pptx-1.0.2-py3-none-any.whl (472 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.8/472.8 kB 31.6 MB/s eta 0:00:00
# Downloading rapidocr-3.4.2-py3-none-any.whl (15.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 85.7 MB/s eta 0:00:00
# Downloading rtree-1.4.1-py3-none-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (507 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.6/507.6 kB 25.1 MB/s eta 0:00:00
# Downloading typer-0.19.2-py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.7/46.7 kB 3.4 MB/s eta 0:00:00
# Downloading faker-37.12.0-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 61.4 MB/s eta 0:00:00
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Downloading jsonref-1.1.0-py3-none-any.whl (9.4 kB)
# Downloading latex2mathml-3.78.1-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.9/73.9 kB 5.6 MB/s eta 0:00:00
# Downloading pyclipper-1.3.0.post6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (963 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 963.8/963.8 kB 29.8 MB/s eta 0:00:00
# Downloading semchunk-2.2.2-py3-none-any.whl (10 kB)
# Downloading xlsxwriter-3.2.9-py3-none-any.whl (175 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.3/175.3 kB 11.8 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Downloading mpire-2.10.2-py3-none-any.whl (272 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 272.8/272.8 kB 18.4 MB/s eta 0:00:00
# Building wheels for collected packages: pylatexenc
#   Building wheel for pylatexenc (setup.py) ... done
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136817 sha256=550083658a69412e5fa7bed67361dde397d42e8a7a8670db3ae69222694e2a4e
#   Stored in directory: /root/.cache/pip/wheels/06/3e/78/fa1588c1ae991bbfd814af2bcac6cef7a178beee1939180d46
# Successfully built pylatexenc
# Installing collected packages: pylatexenc, pyclipper, filetype, XlsxWriter, rtree, python-docx, pypdfium2, mpire, marko, latex2mathml, jsonref, jsonlines, faker, colorlog, rapidocr, python-pptx, polyfactory, typer, semchunk, docling-core, docling-parse, docling-ibm-models, docling
#   Attempting uninstall: typer
#     Found existing installation: typer 0.20.0
#     Uninstalling typer-0.20.0:
#       Successfully uninstalled typer-0.20.0
# Successfully installed XlsxWriter-3.2.9 colorlog-6.10.1 docling-2.58.0 docling-core-2.49.0 docling-ibm-models-3.10.2 docling-parse-4.7.0 faker-37.12.0 filetype-1.2.0 jsonlines-4.0.0 jsonref-1.1.0 latex2mathml-3.78.1 marko-2.2.1 mpire-2.10.2 polyfactory-2.22.3 pyclipper-1.3.0.post6 pylatexenc-2.10 pypdfium2-4.30.0 python-docx-1.2.0 python-pptx-1.0.2 rapidocr-3.4.2 rtree-1.4.1 semchunk-2.2.2 typer-0.19.2
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 77.8 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
from docling.document_converter import DocumentConverter
from pathlib import Path

def read_with_docling(path):
    conv = DocumentConverter()
    result = conv.convert(str(path))
    doc = result.document
    try:
        text = doc.export_to_text()
    except AttributeError:
        text = doc.export_to_markdown()
    return str(text)
if __name__ == "__main__":
    src = "annotations_finance_india_v2.pdf"
    text = read_with_docling(src)
    print(text[:800])
# Out:
# [INFO] 2025-10-30 12:37:51,448 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2025-10-30 12:37:51,456 [RapidOCR] download_file.py:68: Initiating download: https://www.modelscope.cn/models/RapidAI/RapidOCR/resolve/v3.4.0/torch/PP-OCRv4/det/ch_PP-OCRv4_det_infer.pth
# [INFO] 2025-10-30 12:37:53,413 [RapidOCR] download_file.py:82: Download size: 13.83MB
# [INFO] 2025-10-30 12:37:53,643 [RapidOCR] download_file.py:95: Successfully saved to: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2025-10-30 12:37:53,645 [RapidOCR] torch.py:54: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2025-10-30 12:37:53,899 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2025-10-30 12:37:53,900 [RapidOCR] download_file.py:68: Initiating download: https://www.modelscope.cn/models/RapidAI/RapidOCR/resolve/v3.4.0/torch/PP-OCRv4/cls/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2025-10-30 12:37:54,776 [RapidOCR] download_file.py:82: Download size: 0.56MB
# [INFO] 2025-10-30 12:37:54,806 [RapidOCR] download_file.py:95: Successfully saved to: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2025-10-30 12:37:54,808 [RapidOCR] torch.py:54: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2025-10-30 12:37:54,908 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2025-10-30 12:37:54,910 [RapidOCR] download_file.py:68: Initiating download: https://www.modelscope.cn/models/RapidAI/RapidOCR/resolve/v3.4.0/torch/PP-OCRv4/rec/ch_PP-OCRv4_rec_infer.pth
# [INFO] 2025-10-30 12:37:56,287 [RapidOCR] download_file.py:82: Download size: 25.67MB
# [INFO] 2025-10-30 12:37:56,784 [RapidOCR] download_file.py:95: Successfully saved to: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# [INFO] 2025-10-30 12:37:56,786 [RapidOCR] torch.py:54: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# WARNING:docling_core.types.doc.document:Parameter `strict_text` has been deprecated and will be ignored.
# ## Financial Report Entity Annotations
#
# ## 1. Company: AsterFin Capital Ltd.
#
# Entities: AsterFin Capital Ltd. (ORGANISATION)
#
# ## 2. Financial Year: FY 2025-26
#
# Entities: FY 2025-26 (DATE)
#
# 3. Report Date: 05 April 2025
#
# Entities: 05 April 2025 (DATE)
#
# ## 4. Location: Mumbai, Maharashtra, India
#
# Entities: Mumbai, Maharashtra, India (LOCATION)
#
# ## 5. AsterFin Capital Ltd. focuses on retail lending, SME credit, and wealth management across India.
#
# Entities: AsterFin Capital Ltd. (ORGANISATION), India (LOCATION)
#
# ## 6. In Q4 FY 2024-25, the company opened branches in Kochi, Coimbatore, and Visakhapatnam.
#
# Entities: Q4 FY 2024-25 (DATE), Kochi (LOCATION), Coimbatore (LOCATION), Visakhapatnam (LOCATION)
#
# ## 7. Total Revenue: n 1,248,300,000 ( n 124.83 Cr)
#
# Entities: n 1,248,300,000 (MONEY)
#
# ## 8

# %%
import spacy
from collections import defaultdict

def run_spacy_ner(text, model_name="en_core_web_sm"):
    """Return (doc, flat_entities_list, grouped_entities_dict)."""
    nlp = spacy.load(model_name)
    doc = nlp(text)

    flat = []
    grouped = defaultdict(list)
    for ent in doc.ents:
        item = {
            "text": ent.text,
            "label": ent.label_,
            "start_char": ent.start_char,
            "end_char": ent.end_char
        }
        flat.append(item)
        grouped[ent.label_].append(item)
    return doc, flat, dict(grouped)
if __name__ == "__main__":
    sample = "google hired rakesh on January 19, 2014 and paid $50,000."
    doc, flat, grouped = run_spacy_ner(sample)
    print(flat)
    print(grouped.keys())
# Out:
# [{'text': 'google', 'label': 'ORG', 'start_char': 0, 'end_char': 6}, {'text': 'January 19, 2014', 'label': 'DATE', 'start_char': 23, 'end_char': 39}, {'text': '50,000', 'label': 'MONEY', 'start_char': 50, 'end_char': 56}]
# dict_keys(['ORG', 'DATE', 'MONEY'])

# %%
from spacy import displacy
from IPython.display import display, HTML
import spacy
try:
    text
except NameError:
    print("Error: 'text' variable not found. Please run the docling cell (90KifyrE4e01) first to extract text from the PDF.")
    raise
try:
    nlp
except NameError:
     nlp = spacy.load("en_core_web_sm")
doc, flat_entities, grouped_entities = run_spacy_ner(text)

# Generate HTML visualization of entities
html = displacy.render(doc, style="ent", page=True)

# Display the HTML
display(HTML(html))

# You can also print the flat and grouped entities to verify
print("\nFlat Entities:")
print(flat_entities)

print("\nGrouped Entities:")
print(grouped_entities)
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ##
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  Financial Report Entity Annotations<br><br>## 1. Company:
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AsterFin Capital Ltd.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# <br><br>Entities:
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AsterFin Capital Ltd.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (ORGANISATION)<br><br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ## 2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# .
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Financial Year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
# : FY
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2025-26
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# <br><br>Entities: FY
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2025-26
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (DATE)<br><br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# . Report Date:
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     05
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April 2025
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# <br><br>Entities:
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     05 April 2025
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (DATE)<br><br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ## 4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# . Location:
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mumbai
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Maharashtra
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# <br><br>Entities:
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mumbai
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Maharashtra
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  (LOCATION)<br><br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ## 5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# .
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AsterFin Capital Ltd.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  focuses on retail lending,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SME
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  credit, and wealth management across
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .<br><br>Entities:
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AsterFin Capital Ltd.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (ORGANISATION),
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-r
# Flat Entities:
# [{'text': '##', 'label': 'MONEY', 'start_char': 0, 'end_char': 2}, {'text': 'AsterFin Capital Ltd.', 'label': 'ORG', 'start_char': 55, 'end_char': 76}, {'text': 'AsterFin Capital Ltd.', 'label': 'ORG', 'start_char': 88, 'end_char': 109}, {'text': '## 2', 'label': 'MONEY', 'start_char': 126, 'end_char': 130}, {'text': 'Financial Year', 'label': 'EVENT', 'start_char': 132, 'end_char': 146}, {'text': '2025-26', 'label': 'DATE', 'start_char': 151, 'end_char': 158}, {'text': '2025-26', 'label': 'DATE', 'start_char': 173, 'end_char': 180}, {'text': '3', 'label': 'CARDINAL', 'start_char': 189, 'end_char': 190}, {'text': '05', 'label': 'CARDINAL', 'start_char': 205, 'end_char': 207}, {'text': 'April 2025', 'label': 'DATE', 'start_char': 208, 'end_char': 218}, {'text': '05 April 2025', 'label': 'DATE', 'start_char': 230, 'end_char': 243}, {'text': '## 4', 'label': 'MONEY', 'start_char': 252, 'end_char': 256}, {'text': 'Mumbai', 'label': 'GPE', 'start_char': 268, 'end_char': 274}, {'text': 'Maharashtra', 'label': 'ORG', 'start_char': 276, 'end_char': 287}, {'text': 'India', 'label': 'GPE', 'start_char': 289, 'end_char': 294}, {'text': 'Mumbai', 'label': 'GPE', 'start_char': 306, 'end_char': 312}, {'text': 'Maharashtra', 'label': 'ORG', 'start_char': 314, 'end_char': 325}, {'text': 'India', 'label': 'GPE', 'start_char': 327, 'end_char': 332}, {'text': '## 5', 'label': 'MONEY', 'start_char': 345, 'end_char': 349}, {'text': 'AsterFin Capital Ltd.', 'label': 'ORG', 'start_char': 351, 'end_char': 372}, {'text': 'SME', 'label': 'ORG', 'start_char': 400, 'end_char': 403}, {'text': 'India', 'label': 'GPE', 'start_char': 441, 'end_char': 446}, {'text': 'AsterFin Capital Ltd.', 'label': 'ORG', 'start_char': 459, 'end_char': 480}, {'text': 'India', 'label': 'GPE', 'start_char': 497, 'end_char': 502}, {'text': '## 6', 'label': 'MONEY', 'start_char': 515, 'end_char': 519}, {'text': 'Q4', 'label': 'GPE', 'start_char': 524, 'end_char': 526}, {'text': '2024-25', 'label': 'DATE', 'start_char': 530, 'end_char': 537}, {'text': 'Kochi', 'label': 'GPE', 'start_char': 570, 'end_char': 575}, {'text': 'Coimbatore', 'label': 'ORG', 'start_char': 577, 'end_char': 587}, {'text': 'Visakhapatnam', 'label': 'GPE', 'start_char': 593, 'end_char': 606}, {'text': '2024-25', 'label': 'DATE', 'start_char': 625, 'end_char': 632}, {'text': 'Kochi', 'label': 'PERSON', 'start_char': 641, 'end_char': 646}, {'text': 'Coimbatore', 'label': 'ORG', 'start_char': 659, 'end_char': 669}, {'text': 'LOCATION', 'label': 'ORG', 'start_char': 671, 'end_char': 679}, {'text': 'Visakhapatnam', 'label': 'GPE', 'start_char': 682, 'end_char': 695}, {'text': '1,248,300,000', 'label': 'CARDINAL', 'start_char': 731, 'end_char': 744}, {'text': '124.83', 'label': 'CARDINAL', 'start_char': 749, 'end_char': 755}, {'text': '8', 'label': 'MONEY', 'start_char': 799, 'end_char': 800}, {'text': '820,000,000', 'label': 'CARDINAL', 'start_char': 821, 'end_char': 832}, {'text': '820,000,000', 'label': 'CARDINAL', 'start_char': 846, 'end_char': 857}, {'text': 'Fee &amp', 'label': 'ORG', 'start_char': 873, 'end_char': 881}, {'text': 'Commission', 'label': 'ORG', 'start_char': 883, 'end_char': 893}, {'text': '220,500,000', 'label': 'CARDINAL', 'start_char': 897, 'end_char': 908}, {'text': '220,500,000', 'label': 'CARDINAL', 'start_char': 922, 'end_char': 933}, {'text': 'Wealth Management', 'label': 'ORG', 'start_char': 950, 'end_char': 967}, {'text': '207,800,000', 'label': 'CARDINAL', 'start_char': 979, 'end_char': 990}, {'text': '207,800,000', 'label': 'CARDINAL', 'start_char': 1004, 'end_char': 1015}, {'text': '11', 'label': 'CARDINAL', 'start_char': 1025, 'end_char': 1027}, {'text': '540,250,000', 'label': 'CARDINAL', 'start_char': 1053, 'end_char': 1064}, {'text': '540,250,000', 'label': 'CARDINAL', 'start_char': 1078, 'end_char': 1089}, {'text': '12', 'label': 'MONEY', 'start_char': 1102, 'end_char': 1104}, {'text': '210,000,000', 'label': 'CARDINAL', 'start_char': 1127, 'end_char': 1138}, {'text': '210,00 ...
#
# Grouped Entities:
# {'MONEY': [{'text': '##', 'label': 'MONEY', 'start_char': 0, 'end_char': 2}, {'text': '## 2', 'label': 'MONEY', 'start_char': 126, 'end_char': 130}, {'text': '## 4', 'label': 'MONEY', 'start_char': 252, 'end_char': 256}, {'text': '## 5', 'label': 'MONEY', 'start_char': 345, 'end_char': 349}, {'text': '## 6', 'label': 'MONEY', 'start_char': 515, 'end_char': 519}, {'text': '8', 'label': 'MONEY', 'start_char': 799, 'end_char': 800}, {'text': '12', 'label': 'MONEY', 'start_char': 1102, 'end_char': 1104}, {'text': '16', 'label': 'MONEY', 'start_char': 1410, 'end_char': 1412}, {'text': '17', 'label': 'MONEY', 'start_char': 1473, 'end_char': 1475}, {'text': '18', 'label': 'MONEY', 'start_char': 1574, 'end_char': 1576}, {'text': '19', 'label': 'MONEY', 'start_char': 1658, 'end_char': 1660}, {'text': '21', 'label': 'MONEY', 'start_char': 1883, 'end_char': 1885}, {'text': '22', 'label': 'MONEY', 'start_char': 1970, 'end_char': 1972}, {'text': '1,380,000,000', 'label': 'MONEY', 'start_char': 2022, 'end_char': 2035}, {'text': '24', 'label': 'MONEY', 'start_char': 2126, 'end_char': 2128}, {'text': '## 25', 'label': 'MONEY', 'start_char': 2327, 'end_char': 2332}, {'text': '29', 'label': 'MONEY', 'start_char': 2990, 'end_char': 2992}, {'text': '30', 'label': 'MONEY', 'start_char': 3138, 'end_char': 3140}, {'text': '31', 'label': 'MONEY', 'start_char': 3260, 'end_char': 3262}, {'text': '32', 'label': 'MONEY', 'start_char': 3388, 'end_char': 3390}, {'text': '33', 'label': 'MONEY', 'start_char': 3509, 'end_char': 3511}, {'text': '34', 'label': 'MONEY', 'start_char': 3673, 'end_char': 3675}, {'text': '35', 'label': 'MONEY', 'start_char': 3785, 'end_char': 3787}, {'text': '36', 'label': 'MONEY', 'start_char': 3887, 'end_char': 3889}, {'text': '37', 'label': 'MONEY', 'start_char': 4001, 'end_char': 4003}, {'text': '38', 'label': 'MONEY', 'start_char': 4137, 'end_char': 4139}, {'text': '39', 'label': 'MONEY', 'start_char': 4231, 'end_char': 4233}, {'text': '41', 'label': 'MONEY', 'start_char': 4458, 'end_char': 4460}], 'ORG': [{'text': 'AsterFin Capital Ltd.', 'label': 'ORG', 'start_char': 55, 'end_char': 76}, {'text': 'AsterFin Capital Ltd.', 'label': 'ORG', 'start_char': 88, 'end_char': 109}, {'text': 'Maharashtra', 'label': 'ORG', 'start_char': 276, 'end_char': 287}, {'text': 'Maharashtra', 'label': 'ORG', 'start_char': 314, 'end_char': 325}, {'text': 'AsterFin Capital Ltd.', 'label': 'ORG', 'start_char': 351, 'end_char': 372}, {'text': 'SME', 'label': 'ORG', 'start_char': 400, 'end_char': 403}, {'text': 'AsterFin Capital Ltd.', 'label': 'ORG', 'start_char': 459, 'end_char': 480}, {'text': 'Coimbatore', 'label': 'ORG', 'start_char': 577, 'end_char': 587}, {'text': 'Coimbatore', 'label': 'ORG', 'start_char': 659, 'end_char': 669}, {'text': 'LOCATION', 'label': 'ORG', 'start_char': 671, 'end_char': 679}, {'text': 'Fee &amp', 'label': 'ORG', 'start_char': 873, 'end_char': 881}, {'text': 'Commission', 'label': 'ORG', 'start_char': 883, 'end_char': 893}, {'text': 'Wealth Management', 'label': 'ORG', 'start_char': 950, 'end_char': 967}, {'text': 'Marketing &', 'label': 'ORG', 'start_char': 1256, 'end_char': 1267}, {'text': 'Compliance &amp', 'label': 'ORG', 'start_char': 1337, 'end_char': 1352}, {'text': 'Net Profit After Tax', 'label': 'ORG', 'start_char': 1578, 'end_char': 1598}, {'text': 'NPAT', 'label': 'ORG', 'start_char': 1600, 'end_char': 1604}, {'text': 'Gross Loans &amp', 'label': 'ORG', 'start_char': 1887, 'end_char': 1903}, {'text': 'Paytm Payments Bank', 'label': 'ORG', 'start_char': 2156, 'end_char': 2175}, {'text': 'Paytm Payments Bank', 'label': 'ORG', 'start_char': 2240, 'end_char': 2259}, {'text': 'AWS India (', 'label': 'ORG', 'start_char': 2301, 'end_char': 2312}, {'text': 'Amazon Web Services', 'label': 'ORG', 'start_char': 2363, 'end_char': 2382}, {'text': 'Amazon Web Services', 'label': 'ORG', 'start_char': 2411, 'end_char': 2430}, {'text': 'AsterFin', 'label': 'ORG', 'start_char': 2477, 'end_char': 2485}, {'text': 'MoU with HDFC ...
